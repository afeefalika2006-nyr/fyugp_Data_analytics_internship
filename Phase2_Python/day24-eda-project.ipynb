# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("employee_mini_project_dataset.csv")

# %%
df.head()
# Out:
#    EmployeeID        Name  Gender   Age       City Department Education  \
# 0           1  Employee_1  Female   NaN     Mumbai     Sales      BTech
# 1           2  Employee_2  Female  21.0    Kolkata   Finance        MCA
# 2           3  Employee_3    Male  56.0  Hyderabad        IT        MBA
# 3           4  Employee_4  Female  25.0    Chennai        IT      BTech
# 4           5  Employee_5    Male  28.0      Delhi        HR        BSc
#
#   WorkMode  Experience    Salary  PerformanceScore  AttendancePercent  \
# 0   Office           2   34683.0              69.0                 65
# 1   Office          19   87236.0               NaN                 91
# 2   Hybrid           6  128520.0              99.0                 65
# 3   Remote           8  116639.0              85.0                 92
# 4   Office          18  144081.0               NaN                 69
#
#    ProjectsCompleted  OvertimeHours  SatisfactionScore  TrainingHours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5100 entries, 0 to 5099
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeID         5100 non-null   int64
#  1   Name               5100 non-null   object
#  2   Gender             5100 non-null   object
#  3   Age                4840 non-null   float64
#  4   City               5100 non-null   object
#  5   Department         5100 non-null   object
#  6   Education          5100 non-null   object
#  7   WorkMode           5100 non-null   object
#  8   Experience         5100 non-null   int64
#  9   Salary             4849 non-null   object
#  10  PerformanceScore   4847 non-null   float64
#  11  AttendancePercent  5100 non-null   int64
#  12  ProjectsCompleted  5100 non-null   int64
#  13  OvertimeHours      5100 non-null   int64
#  14  SatisfactionScore  5100 non-null   int64
#  15  TrainingHours      5100 non-null   int64
# ...

# %%
df.describe()
# Out:
#         EmployeeID          Age   Experience  PerformanceScore  \
# count  5100.000000  4840.000000  5100.000000       4847.000000
# mean   2502.549608    39.536777    13.030000         79.929028
# std    1443.640777    11.073665     7.258168         11.793568
# min       1.000000    21.000000     1.000000         60.000000
# 25%    1253.750000    30.000000     7.000000         70.000000
# 50%    2500.500000    40.000000    13.000000         80.000000
# 75%    3754.250000    49.000000    19.000000         90.000000
# max    5000.000000    58.000000    25.000000        100.000000
#
#        AttendancePercent  ProjectsCompleted  OvertimeHours  SatisfactionScore  \
# count        5100.000000        5100.000000    5100.000000        5100.000000
# mean           82.521961           7.918627      20.020196           5.446667
# std            10.332372           4.277656      11.805883           2.902565
# min            65.000000           1.000000       0.000000           1.000000
# ...

# %%
df.shape
# Out:
# (5100, 17)

# %%
df.isnull().sum()
# Out:
# EmployeeID             0
# Name                   0
# Gender                 0
# Age                  260
# City                   0
# Department             0
# Education              0
# WorkMode               0
# Experience             0
# Salary               251
# PerformanceScore     253
# AttendancePercent      0
# ProjectsCompleted      0
# OvertimeHours          0
# SatisfactionScore      0
# TrainingHours          0
# LeavesTaken            0
# dtype: int64

# %%
df["Department"] = df["Department"].str.strip()

# %%
df["Salary"] = pd.to_numeric(df["Salary"], errors="coerce")

# %%
df["Salary"].fillna(df["Salary"].mean(), inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14268\2346652894.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Salary"].fillna(df["Salary"].mean(), inplace=True)

# %%
df["Age"].fillna(df["Age"].mean(), inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14268\1809399462.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(), inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (5005, 17)

# %%
df.isnull().sum()
# Out:
# EmployeeID             0
# Name                   0
# Gender                 0
# Age                    0
# City                   0
# Department             0
# Education              0
# WorkMode               0
# Experience             0
# Salary                 0
# PerformanceScore     250
# AttendancePercent      0
# ProjectsCompleted      0
# OvertimeHours          0
# SatisfactionScore      0
# TrainingHours          0
# LeavesTaken            0
# dtype: int64

# %%
df["PerformanceScore"] = pd.to_numeric(df["PerformanceScore"], errors="coerce")

# %%
df.isnull().sum()
# Out:
# EmployeeID             0
# Name                   0
# Gender                 0
# Age                    0
# City                   0
# Department             0
# Education              0
# WorkMode               0
# Experience             0
# Salary                 0
# PerformanceScore     250
# AttendancePercent      0
# ProjectsCompleted      0
# OvertimeHours          0
# SatisfactionScore      0
# TrainingHours          0
# LeavesTaken            0
# dtype: int64

# %%
df["PerformanceScore"].fillna(df["PerformanceScore"].mean(), inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14268\1438301278.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["PerformanceScore"].fillna(df["PerformanceScore"].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# EmployeeID           0
# Name                 0
# Gender               0
# Age                  0
# City                 0
# Department           0
# Education            0
# WorkMode             0
# Experience           0
# Salary               0
# PerformanceScore     0
# AttendancePercent    0
# ProjectsCompleted    0
# OvertimeHours        0
# SatisfactionScore    0
# TrainingHours        0
# LeavesTaken          0
# dtype: int64

# %%
df.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance       90853.420458
# HR            91738.304799
# IT            92808.067058
# Marketing     90554.616625
# Operations    94505.526020
# Sales         91806.218132
# Support       92343.634648
# nan           89297.614643
# Name: Salary, dtype: float64

# %%
df["Department"] = df["Department"].str.strip()

df["Department"] = df["Department"].replace("nan","clean")

# %%
df.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance       90853.420458
# HR            91738.304799
# IT            92808.067058
# Marketing     90554.616625
# Operations    94505.526020
# Sales         91806.218132
# Support       92343.634648
# clean         89297.614643
# Name: Salary, dtype: float64

# %%
df["City"].value_counts()
# Out:
# City
# Mumbai       632
# Chennai      631
# Kolkata      626
# Delhi        622
# Hyderabad    619
# Pune         617
# Bangalore    605
# Kochi        603
# mumbai        10
# kochi          7
# hyderabad      7
# chennai        7
# kolkata        7
# pune           6
# bangalore      4
# delhi          2
# Name: count, dtype: int64

# %%
df.groupby("Gender")["PerformanceScore"].mean()
# Out:
# Gender
# Female    79.647636
# Male      80.156679
# Name: PerformanceScore, dtype: float64

# %%
df[df["Salary"] > 100000]
# Out:
#       EmployeeID           Name  Gender   Age       City  Department  \
# 2              3     Employee_3    Male  56.0  Hyderabad          IT
# 3              4     Employee_4  Female  25.0    Chennai          IT
# 4              5     Employee_5    Male  28.0      Delhi          HR
# 5              6     Employee_6  Female  24.0     Mumbai  Operations
# 6              7     Employee_7  Female  30.0  Hyderabad     Support
# ...          ...            ...     ...   ...        ...         ...
# 4991        4992  Employee_4992    Male  50.0      Kochi  Operations
# 4994        4995  Employee_4995    Male  52.0    Kolkata       Sales
# 4995        4996  Employee_4996  Female  39.0    Kolkata     Finance
# 5042        2661  Employee_2661  Female  25.0      Kochi          IT
# 5046        2806  Employee_2806  Female  49.0       pune       Sales
#
#      Education WorkMode  Experience    Salary  PerformanceScore  \
# 2          MBA   Hybrid           6  128520.0         99.000000
# ...

# %%
dept_salary = df.groupby("Department")["Salary"].mean()

plt.figure(figsize=(8,5))

plt.bar(dept_salary.index, dept_salary.values,
        color="steelblue", edgecolor="black")

plt.title("Average Salary by Department", fontsize=14, fontweight="bold")
plt.xlabel("Department")
plt.ylabel("Average Salary")

plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df["Experience"], df["Salary"],color="steelblue")

plt.title("Experience vs Salary", fontsize=14, fontweight="bold")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.grid(alpha=0.5)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Salary"],bins=10,color="steelblue",edgecolor="black")

plt.title("Salary Distribution", fontsize=14, fontweight="bold")
plt.xlabel("Salary")
plt.ylabel("Frequency")

plt.grid(axis="y", alpha=0.5)

plt.tight_layout()
plt.show()

# %%
plt.boxplot(df["Salary"])

plt.title("Salary Box Plot")

plt.show()

# %%
# Observation:-
#1- Finance and IT departments have the highest average salaries.

#2- Most employees earn salaries in the middle salary range.

#3- Employees with higher experience generally earn more.

#4- A few employees have unusually high salaries compared to others.

#5- Employee distribution across cities is fairly balanced.

# %%
# What I Would Explore Next :-
# I would like to explore whether overtime hours affect employee performance scores.
# I want to analyze whether employee satisfaction is related to salary and work mode.
# I would also explore which education level is associated with higher salaries and promotions.
