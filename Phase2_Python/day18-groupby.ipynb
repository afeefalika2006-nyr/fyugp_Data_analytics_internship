# %%
import pandas as pd

df = pd.read_csv("sales_large.csv")
df["Total"] = df["Quantity"] * df["Price"]

# %%
df.groupby("Category")["Total"].sum()
# Out:
# Category
# Electronics    957700
# Furniture      265100
# Name: Total, dtype: int64

# %%
df.groupby("Category")["Total"].mean()
# Out:
# Category
# Electronics    35470.370370
# Furniture      11526.086957
# Name: Total, dtype: float64

# %%
df["Category"].value_counts()
# Out:
# Category
# Electronics    27
# Furniture      23
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    OrderID Customer Region     Product     Category  Quantity  Price  \
# 0     1001    Afeef  South      Laptop  Electronics         1  50000
# 1     1002    Rahul  North       Phone  Electronics         2  20000
# 2     1003    Meena   West       Table    Furniture         1   7000
# 3     1004     John   East       Chair    Furniture         4   1500
# 4     1005      Anu  South  Headphones  Electronics         3   2000
#
#     OrderDate  Total
# 0  2024-01-10  50000
# 1  2024-01-12  40000
# 2  2024-01-15   7000
# 3  2024-01-18   6000
# 4  2024-01-20   6000
