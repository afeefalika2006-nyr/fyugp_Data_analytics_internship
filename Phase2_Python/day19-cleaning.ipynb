# %%
import pandas as pd

df = pd.read_csv("Messy_Sales_Data.csv")

df.head()
# Out:
#    Order ID Customer Name       Product     Category  Order Date Quantity  \
# 0    1001.0      John Doe        Laptop  Electronics  01-01-2024        1
# 1    1002.0   Jane Smith     Smartphone  Electronics  02/01/2024        2
# 2    1003.0   Rahul Kumar    Headphones  Electronics  03-01-2024        3
# 3    1004.0   Emily Davis  Office Chair    Furniture  04-01-2024        1
# 4    1005.0     Ahmed Ali          Desk    Furniture  05-01-2024        2
#
#   Unit Price  Total Amount         City  Payment Method
# 0        750         750.0     New York     Credit Card
# 1        500        1000.0  Los Angeles      Debit Card
# 2         50         150.0       Mumbai            Cash
# 3        120         120.0       London     Credit Card
# 4        200         400.0        Dubai  Online Payment

# %%
df.isnull().sum()
# Out:
# Order ID          1
# Customer Name     1
# Product           0
# Category          0
# Order Date        0
# Quantity          1
# Unit Price        0
# Total Amount      1
# City              0
# Payment Method    0
# dtype: int64

# %%
df = df.dropna(subset=["Order ID"])

df.isnull().sum()
# Out:
# Order ID          0
# Customer Name     1
# Product           0
# Category          0
# Order Date        0
# Quantity          1
# Unit Price        0
# Total Amount      1
# City              0
# Payment Method    0
# dtype: int64

# %%
df["Customer Name"] = df["Customer Name"].fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# Order ID          0
# Customer Name     0
# Product           0
# Category          0
# Order Date        0
# Quantity          1
# Unit Price        0
# Total Amount      1
# City              0
# Payment Method    0
# dtype: int64

# %%
df = df.drop_duplicates()

df.shape
# Out:
# (23, 10)

# %%
df["Quantity"] = pd.to_numeric(df["Quantity"], errors="coerce")
df["Unit Price"] = pd.to_numeric(df["Unit Price"], errors="coerce")

# %%
df["Quantity"] = df["Quantity"].fillna(df["Total Amount"]/df["Unit Price"])

# %%
df["Unit Price"] = df["Unit Price"].fillna(df["Total Amount"]/df["Quantity"])

# %%
df["Total Amount"] = df["Total Amount"].fillna(df["Quantity"] * df["Unit Price"])

# %%
df.isnull().sum()
# Out:
# Order ID          0
# Customer Name     0
# Product           0
# Category          0
# Order Date        0
# Quantity          0
# Unit Price        0
# Total Amount      0
# City              0
# Payment Method    0
# dtype: int64

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 0 to 23
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        23 non-null     float64
#  1   Customer Name   23 non-null     object
#  2   Product         23 non-null     object
#  3   Category        23 non-null     object
#  4   Order Date      23 non-null     object
#  5   Quantity        23 non-null     float64
#  6   Unit Price      23 non-null     float64
#  7   Total Amount    23 non-null     float64
#  8   City            23 non-null     object
#  9   Payment Method  23 non-null     object
# dtypes: float64(4), object(6)
# memory usage: 2.0+ KB
#    Order ID Customer Name       Product     Category  Order Date  Quantity  \
# 0    1001.0      John Doe        Laptop  Electronics  01-01-2024       1.0
# 1    1002.0   Jane Smith     Smartphone  Electronics  02/01/2024       2.0
# 2    1003.0   Rahul Kumar    Headphones  Electronics  03-01-2024       3.0
# 3    1004.0   Emily Davis  Office Chair    Furniture  04-01-2024       1.0
# 4    1005.0     Ahmed Ali          Desk    Furniture  05-01-2024       2.0
#
#    Unit Price  Total Amount         City  Payment Method
# 0       750.0         750.0     New York     Credit Card
# 1       500.0        1000.0  Los Angeles      Debit Card
# 2        50.0         150.0       Mumbai            Cash
# 3       120.0         120.0       London     Credit Card
# 4       200.0         400.0        Dubai  Online Payment

# %%
df.to_csv("cleaned_sales_data.csv", index=False)
