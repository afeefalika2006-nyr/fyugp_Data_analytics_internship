# %%
# This notebook is my first Python practice.
# It stores my personal details and calculates my age in different units.

# %%
#pgm1
name = "Afeef"
age = 20
city = "Kochi"

# %%
age_months = age * 12
age_days = age * 365
age_hours = age_days * 24

# %%
print("Name:", name)
print("City:", city)
print("Age in months:", age_months)
print("Age in days:", age_days)
print("Age in hours:", age_hours)
# Out:
# Name: Afeef
# City: Kochi
# Age in months: 240
# Age in days: 7300
# Age in hours: 175200

# %%
# This line contains an error
print(Age in months: age_months)
# Out:
#   Cell In[6], line 2
#     print(Age in months: age_months)
#                        ^
# SyntaxError: invalid syntax

# %%
# The error occurs because the text inside print() is not in quotes.
# Python thinks "Age" is a variable, which is not defined.
# This causes a SyntaxError or NameError.
