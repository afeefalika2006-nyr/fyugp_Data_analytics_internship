# %%
import pandas as pd

df = pd.read_csv("sales_large.csv")

# %%
df[["Product", "Price"]]
# Out:
#        Product  Price
# 0       Laptop  50000
# 1        Phone  20000
# 2        Table   7000
# 3        Chair   1500
# 4   Headphones   2000
# 5       Laptop  55000
# 6         Sofa  20000
# 7        Phone  22000
# 8        Chair   1800
# 9        Table   7500
# 10      Laptop  52000
# 11  Headphones   2500
# 12       Phone  21000
# 13        Sofa  18000
# 14       Chair   1700
# 15      Laptop  53000
# 16       Table   8000
# 17       Phone  23000
# 18  Headphones   1800
# 19        Sofa  21000
# 20      Laptop  51000
# 21       Chair   1600
# 22       Phone  19000
# 23       Table   7800
# 24  Headphones   2200
# 25        Sofa  20000
# 26      Laptop  54000
# 27       Phone  24000
# 28       Chair   1500
# 29       Table   7600
# 30  Headphones   2100
# 31      Laptop  56000
# 32       Phone  20500
# 33       Chair   1400
# 34        Sofa  19500
# 35       Table   8200
# 36  Headphones   1900
# 37      Laptop  57000
# 38       Phone  22500
# 39       Chair   1600
# ...

# %%
df[df["Price"] > df["Price"].mean()]
# Out:
#     OrderID Customer Region Product     Category  Quantity  Price   OrderDate
# 0      1001    Afeef  South  Laptop  Electronics         1  50000  2024-01-10
# 1      1002    Rahul  North   Phone  Electronics         2  20000  2024-01-12
# 5      1006     Ravi  North  Laptop  Electronics         1  55000  2024-01-22
# 6      1007     Neha   West    Sofa    Furniture         1  20000  2024-01-25
# 7      1008      Ali   East   Phone  Electronics         2  22000  2024-01-28
# 10     1011     Aman   West  Laptop  Electronics         1  52000  2024-02-07
# 12     1013    Kiran  South   Phone  Electronics         1  21000  2024-02-12
# 15     1016   Sameer   East  Laptop  Electronics         1  53000  2024-02-20
# 17     1018     Manu  North   Phone  Electronics         1  23000  2024-02-25
# 19     1020    Sneha   East    Sofa    Furniture         1  21000  2024-03-02
# 20     1021    Akhil  South  Laptop  Electronics         1  51000  2024-03-05
# ...

# %%
df.sort_values("Price", ascending=False)
# Out:
#     OrderID Customer Region     Product     Category  Quantity  Price  \
# 49     1050     Ritu  North      Laptop  Electronics         1  59000
# 43     1044     Omar   East      Laptop  Electronics         1  58000
# 37     1038    Priya  North      Laptop  Electronics         1  57000
# 31     1032     Arif   East      Laptop  Electronics         1  56000
# 5      1006     Ravi  North      Laptop  Electronics         1  55000
# 26     1027    Latha   West      Laptop  Electronics         1  54000
# 15     1016   Sameer   East      Laptop  Electronics         1  53000
# 10     1011     Aman   West      Laptop  Electronics         1  52000
# 20     1021    Akhil  South      Laptop  Electronics         1  51000
# 0      1001    Afeef  South      Laptop  Electronics         1  50000
# 27     1028    Imran   East       Phone  Electronics         2  24000
# 17     1018     Manu  North       Phone  Electronics         1  23000
# ...

# %%
df[(df["Region"] == "South") & (df["Price"] > 20000)]
# Out:
#     OrderID Customer Region Product     Category  Quantity  Price   OrderDate
# 0      1001    Afeef  South  Laptop  Electronics         1  50000  2024-01-10
# 12     1013    Kiran  South   Phone  Electronics         1  21000  2024-02-12
# 20     1021    Akhil  South  Laptop  Electronics         1  51000  2024-03-05
# 32     1033    Kavya  South   Phone  Electronics         2  20500  2024-04-06
# 40     1041     Asha  South    Sofa    Furniture         1  22000  2024-04-25
# 44     1045     Tina  South   Phone  Electronics         2  21500  2024-05-05
